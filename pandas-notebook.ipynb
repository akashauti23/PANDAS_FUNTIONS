# %% [markdown]
# # Import :- Importing libraries.

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# # pd.series :- covert list to 1D array.

# %%
"""Creating a Series by passing a list of values, letting pandas create a default integer index:"""
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# # pd.DataFrame :- Convert Dictionary into Dataframe.

# %%
"""Creating a DataFrame by passing a dictionary of objects that can be converted into a series-like structure"""
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# # pd.read :- Import needed File.

# %%
"""Reading data files"""
df=pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv")

# %% [markdown]
# # pd.read (index_col=0) :- Import needed File while coverting first column into index.

# %%
"""Reading data files and seting a column as index"""
df=pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv",index_col=0)

# %% [markdown]
# # df.head() :- Getting first 5 values of df.

# %%
"""Getting first five values of dataset"""
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# # df.tail() :- Getting last 5 values of df.

# %%
"""Returns the headers and the last rows"""
df.tail()
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %% [markdown]
# # df.shape :- Getting Dimensions of df.

# %%
"""We can use the shape attribute to check how large the resulting DataFrame is"""
df.shape
# Out:
# (129971, 13)

# %% [markdown]
# # len(df) :- Getting legth (No. of content) of df.

# %%
"""Provides with the length of the DataFrame"""
len(df)
# Out:
# 129971

# %% [markdown]
# # df.describe() :- To have a brief Description.

# %%
"""used to generate descriptive statistics of the data in a Pandas DataFrame or Series. It summarizes central tendency and dispersion of the dataset. """
df.describe()
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# std         3.039730      41.022218
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %% [markdown]
# # df.columns :- To get list of Columns.

# %%
"""see all the columns. using .columns function"""
df.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %% [markdown]
# # df.info() :- To get brief info. about df. (Mainly null values.)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                129908 non-null  object
#  1   description            129971 non-null  object
#  2   designation            92506 non-null   object
#  3   points                 129971 non-null  int64
#  4   price                  120975 non-null  float64
#  5   province               129908 non-null  object
#  6   region_1               108724 non-null  object
#  7   region_2               50511 non-null   object
#  8   taster_name            103727 non-null  object
#  9   taster_twitter_handle  98758 non-null   object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 13.9+ MB

# %% [markdown]
# # df.memory_usage() :- To get total memory being used by each column

# %%
"""memory_usage() returns a Pandas Series having the memory usage of each column (in bytes) in a Pandas DataFrame"""
df.memory_usage()
# Out:
# Index                    1039768
# country                  1039768
# description              1039768
# designation              1039768
# points                   1039768
# price                    1039768
# province                 1039768
# region_1                 1039768
# region_2                 1039768
# taster_name              1039768
# taster_twitter_handle    1039768
# title                    1039768
# variety                  1039768
# winery                   1039768
# dtype: int64

# %% [markdown]
# # .astype('') :- To cast particular column in particular format.

# %%
"""astype() is used to cast a Python object to a particular data type"""
df['price'] = df['price'].astype('object')

# %% [markdown]
# # .iloc[ ] (Slicing) - To get the specified no. of rows from df.

# %%
"""oc[:] helps to access a group of rows and columns in a dataset, a slice of the dataset, as per our requirement"""
df.loc[0:4]
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points price           province  \
# 0                        Vulkà Bianco      87   NaN  Sicily & Sardinia
# 1                            Avidagos      87  15.0              Douro
# 2                                 NaN      87  14.0             Oregon
# 3                Reserve Late Harvest      87  13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87  65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# # Slicing - To get the specified no. of rows from df including mentioned columns.
# *** [] :- mentioned columns will be displayed only.**

# %%
"""oc[:] helps to access a group of rows and columns in a dataset, a slice of the dataset, as per our requirement"""
df.loc[0:4, ['country', 'points', 'variety']]
# Out:
#     country  points         variety
# 0     Italy      87     White Blend
# 1  Portugal      87  Portuguese Red
# 2        US      87      Pinot Gris
# 3        US      87        Riesling
# 4        US      87      Pinot Noir

# %%
# """to_datetime() converts a Python object to datetime format."""
# data_1['DOB'] = pd.to_datetime(data_1['DOB'])

# %% [markdown]
# # .value_count() :- Return a Series containing counts of unique values

# %%
"""value_counts() returns a Pandas Series containing the counts of unique values."""
df['country'].value_counts()
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %% [markdown]
# # .drop_duplicates :- To remove rows with duplicate Values
# *** (inplace=True) :- to replace new df wiht  old df**

# %%
"""drop_duplicates() returns a Pandas DataFrame with duplicate rows removed"""
df.drop_duplicates(inplace=True)

# %% [markdown]
# # df.groupby :- grouping the data according to the categories

# %%
"""groupby() is used to group a Pandas DataFrame by 1 or more columns, and perform some mathematical operation on it. """
df.groupby('country').points.mean()
# Out:
# country
# Argentina                 86.649831
# Armenia                   87.500000
# Australia                 88.561220
# Austria                   90.129532
# Bosnia and Herzegovina    86.500000
# Brazil                    84.632653
# Bulgaria                  87.878788
# Canada                    89.309735
# Chile                     86.460564
# China                     89.000000
# Croatia                   87.185714
# Cyprus                    87.100000
# Czech Republic            87.090909
# Egypt                     84.000000
# England                   91.746032
# France                    88.866752
# Georgia                   87.605263
# Germany                   89.895582
# Greece                    87.238426
# Hungary                   89.294574
# India                     90.250000
# Israel                    88.454936
# Italy                     88.576198
# Lebanon                   87.593750
# Luxembourg                88.800000
# Macedonia                 86.818182
# ...

# %% [markdown]
# # df.merge :- to merge two different df.
# *** (on='') :- to Merge on specified column name**

# %%
# """merge() is used to merge 2 Pandas DataFrame"""
# data_1.merge(data_2, on='Name', how='left')

# %% [markdown]
# # df.sort_values :- To sort values of mentioned Column
# *** (inplace=True) :- To replace df.**
# *** (ascending=False) :- To specify the order of sorting.**

# %%
"""sort_values() is used to sort column in a Pandas DataFrame (or a Pandas Series) by values in ascending or descending order."""
df.sort_values(by='country', inplace=True)
df.sort_values(by='country', inplace=True,ascending=False)

# %% [markdown]
# # fillna :- TO fill NAN vlaues in df.
# *** ffill :- to fill forward values of NAN cell.**
# *** bfill :- to fill backward values of NAN cell.**

# %%
"""fillna() helps to replace all NaN values in a DataFrame or Series by imputing these missing values with more appropriate values."""
df['price'].fillna(38.5, inplace=True)
df['price'].fillna(df['price'].mean(), inplace=True)
df['price'].fillna(df['price'].median(), inplace=True)
df['price'].fillna(df['price'].mode(), inplace=True)
df['designation'].ffill(axis=0,inplace=True)
df['designation'].bfill(axis=0,inplace=True)

# %% [markdown]
# # df.drop() :- to drop specified columns.

# %%
"""drop some unnecessary columns using df.drop()"""
df = df.drop(columns=['region_2', 'region_1'])

# %% [markdown]
# # .iloc[ ] (Slicing) - To get the specified no. of rows from df.

# %%
"""This function takes as a parameter the rows and column indices and gives you the subset of the DataFrame accordingly."""
df.iloc[:10, 5:10]
# Out:
#          province        taster_name taster_twitter_handle  \
# 19512   Canelones  Michael Schachner           @wineschach
# 55673   Atlantida  Michael Schachner           @wineschach
# 25497     Uruguay  Michael Schachner           @wineschach
# 48301   Canelones  Michael Schachner           @wineschach
# 124223  Canelones  Michael Schachner           @wineschach
# 39361     Uruguay  Michael Schachner           @wineschach
# 14722     Juanico  Michael Schachner           @wineschach
# 25485   Canelones  Michael Schachner           @wineschach
# 14723    San Jose  Michael Schachner           @wineschach
# 37960     Uruguay  Michael Schachner           @wineschach
#
#                                                     title  \
# 19512    Marichal 2013 Grand Reserve A Tannat (Canelones)
# 55673   Bracco Bosca 2016 Ombú Reserve Tannat (Atlantida)
# 25497   Alto de la Ballena 2011 Reserve Tannat-Viognie...
# 48301        Gimenez Mendez 2007 Identity Red (Canelones)
# ...

# %% [markdown]
# # df.query() :- To filter or to ask if True or False

# %%
"""You can filter or query using a boolean expression"""
df.query("points > price")
# Out:
#         country                                        description  \
# 19512   Uruguay  A lot has been thrown at this Tannat, and thus...
# 55673   Uruguay  Oaky spice aromas are up front on a nose that ...
# 25497   Uruguay  This Tannat (with 15% Viognier) is full and oa...
# 48301   Uruguay  Dark, roasted and smelling of licorice, root b...
# 124223  Uruguay  While this smells a bit rough and herbal, it's...
# ...         ...                                                ...
# 124176      NaN  This Swiss red blend is composed of four varie...
# 129407      NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408      NaN  El Capricho is one of Uruguay's more consisten...
# 129590      NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900      NaN  This wine offers a delightful bouquet of black...
#
#                     designation  points  price   province        taster_name  \
# 19512           Grand Reserve A      84   65.0  Canelones  Michael Schachner
# ...

# %% [markdown]
# # df.select_dtypes() :- To select the specified Datatype columns only.

# %%
"""Getting only categorical columns in a dataset"""
df.select_dtypes(include=object)
# Out:
#         country                                        description  \
# 19512   Uruguay  A lot has been thrown at this Tannat, and thus...
# 55673   Uruguay  Oaky spice aromas are up front on a nose that ...
# 25497   Uruguay  This Tannat (with 15% Viognier) is full and oa...
# 48301   Uruguay  Dark, roasted and smelling of licorice, root b...
# 124223  Uruguay  While this smells a bit rough and herbal, it's...
# ...         ...                                                ...
# 124176      NaN  This Swiss red blend is composed of four varie...
# 129407      NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408      NaN  El Capricho is one of Uruguay's more consisten...
# 129590      NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900      NaN  This wine offers a delightful bouquet of black...
#
#                     designation   province        taster_name  \
# 19512           Grand Reserve A  Canelones  Michael Schachner
# ...

# %%
"""Incase of all numeric values we will add mean in place of null values"""
num=df.select_dtypes(exclude=object)
num
# Out:
#         points  price
# 19512       84   65.0
# 55673       88   21.0
# 25497       88   19.0
# 48301       85   20.0
# 124223      84   16.0
# ...        ...    ...
# 124176      90   30.0
# 129407      89   22.0
# 129408      89   22.0
# 129590      90   30.0
# 129900      91   32.0
#
# [119988 rows x 2 columns]

# %% [markdown]
# # df().dtypes :- To find the datatype of mentioned column.

# %%
"""know the data types of the variables """
df['description'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# # np.random.randint() :- To receive random integers of mentioned length.

# %%
"""it inserts a column in the specified position"""
random_col = np.random.randint(100, size=len(df))
df.insert(3, 'random_col', random_col)

# %% [markdown]
# # df.cumsum() :- To get the commulative sumation of given column.

# %%
df[['points', 'price']].cumsum()
# Out:
#           points      price
# 19512         84       65.0
# 55673        172       86.0
# 25497        260      105.0
# 48301        345      125.0
# 124223       429      141.0
# ...          ...        ...
# 124176  10611648  4298127.5
# 129407  10611737  4298149.5
# 129408  10611826  4298171.5
# 129590  10611916  4298201.5
# 129900  10612007  4298233.5
#
# [119988 rows x 2 columns]

# %% [markdown]
# # df.sample() :- To receive the rondom sample rows and columns from df.

# %%
"""When the size of the dataset is too big, you can take a representative sample from it to perform the analysis and predictive modeling."""
df.sample(n = 200)
df.sample(frac = 0.25)
# Out:
#          country                                        description  \
# 81469         US  This winery's Pinots rarely rise to the top, b...
# 51803         US  Soft baking-spice notes mesh with vanilla, red...
# 117407        US  You never quite know what you're getting with ...
# 11894     France  This single-vineyard wine is rich and crisply ...
# 14466     France  Tannat and Pinenc, both native to this region ...
# ...          ...                                                ...
# 76681   Portugal  This is a fun, candy-pink colored wine that is...
# 91211         US  It was difficult to get much out of the glass;...
# 58838         US  This wine over-delivers in quality for the pri...
# 51938     France  A blend of Riesling, Pinot Gris, Gewurztramine...
# 113007    France  The Haut-Brion winemaking team produces this r...
#
#                                designation  random_col  points  price  \
# 81469                      Special Reserve          80      89   35.0
# ...

# %%
"""This function helps you query a dataset based on a boolean condition"""
df['random_col'].where(df['random_col'] > 50)
df['random_col'].where(df['random_col'] > 50, 0)
# Out:
# 19512      0
# 55673     80
# 25497     84
# 48301      0
# 124223    80
#           ..
# 124176     0
# 129407    79
# 129408    53
# 129590    77
# 129900     0
# Name: random_col, Length: 119988, dtype: int64

# %% [markdown]
# # df.unique() :- To find the unique values of specified Column.

# %%
"""It is used to find out the unique values of a categorical column."""
df['country'].unique()
# Out:
# array(['Uruguay', 'Ukraine', 'US', 'Turkey', 'Switzerland', 'Spain',
#        'South Africa', 'Slovenia', 'Slovakia', 'Serbia', 'Romania',
#        'Portugal', 'Peru', 'New Zealand', 'Morocco', 'Moldova', 'Mexico',
#        'Macedonia', 'Luxembourg', 'Lebanon', 'Italy', 'Israel', 'India',
#        'Hungary', 'Greece', 'Germany', 'Georgia', 'France', 'England',
#        'Egypt', 'Czech Republic', 'Cyprus', 'Croatia', 'China', 'Chile',
#        'Canada', 'Bulgaria', 'Brazil', 'Bosnia and Herzegovina',
#        'Austria', 'Australia', 'Armenia', 'Argentina', nan], dtype=object)

# %%
"""This function lets you know how many unique values do you have in a column"""
df['province'].nunique()
# Out:
# 425

# %% [markdown]
# # df.isin() :- To check if the column actually contains the specified values.

# %%
"""This function checks returns the values in that dataset """
nationality = ["Argentina", "England"]
df[df.country.isin(nationality)]
# Out:
#           country                                        description  \
# 72070     England  A fragrant, sherbety cloud of spring meadow an...
# 72824     England  A haze of summer flowers hovers across a fizzy...
# 56417     England  Notes of apple immediately rise from the glass...
# 60002     England  Beautifully delineated fruit constitues the no...
# 27356     England  Freshly cut peel of tart but ripe red apple en...
# ...           ...                                                ...
# 47523   Argentina  Tapiz's best wine to date, and the first one t...
# 127975  Argentina  Murky, earthy aromas of plum and red berry fee...
# 81893   Argentina  Ripe and saturated on the nose, this big boy i...
# 21420   Argentina  Amancaya, a blend of Malbec and Cabernet Sauvi...
# 24050   Argentina  Big, bulky and granular, with high alcohol and...
#
#                           designation  random_col  points  price  \
# 72070            Blanc de Blancs Brut          97      91   50.0
# ...

# %% [markdown]
# # df.replace() :- To replace mentioned values with new value.

# %%
""" When we need to replace only one unique value of a column """
df.replace("India", "INDIA")
# Out:
#         country                                        description  \
# 19512   Uruguay  A lot has been thrown at this Tannat, and thus...
# 55673   Uruguay  Oaky spice aromas are up front on a nose that ...
# 25497   Uruguay  This Tannat (with 15% Viognier) is full and oa...
# 48301   Uruguay  Dark, roasted and smelling of licorice, root b...
# 124223  Uruguay  While this smells a bit rough and herbal, it's...
# ...         ...                                                ...
# 124176      NaN  This Swiss red blend is composed of four varie...
# 129407      NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408      NaN  El Capricho is one of Uruguay's more consisten...
# 129590      NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900      NaN  This wine offers a delightful bouquet of black...
#
#                     designation  random_col  points  price   province  \
# 19512           Grand Reserve A          27      84   65.0  Canelones
# ...

# %% [markdown]
# # df.rename() :- To replce name of columns with new one.

# %%
"""It is used to rename the column/s."""
df.rename(columns = {"country": "Country", "price": "Price"})
# Out:
#         Country                                        description  \
# 19512   Uruguay  A lot has been thrown at this Tannat, and thus...
# 55673   Uruguay  Oaky spice aromas are up front on a nose that ...
# 25497   Uruguay  This Tannat (with 15% Viognier) is full and oa...
# 48301   Uruguay  Dark, roasted and smelling of licorice, root b...
# 124223  Uruguay  While this smells a bit rough and herbal, it's...
# ...         ...                                                ...
# 124176      NaN  This Swiss red blend is composed of four varie...
# 129407      NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408      NaN  El Capricho is one of Uruguay's more consisten...
# 129590      NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900      NaN  This wine offers a delightful bouquet of black...
#
#                     designation  random_col  points  Price   province  \
# 19512           Grand Reserve A          27      84   65.0  Canelones
# ...

# %%
"""It provides you the number of data in the DataFrame in the specified direction"""
df.count(0)
# Out:
# country                  119929
# description              119988
# designation              119988
# random_col               119988
# points                   119988
# price                    119988
# province                 119929
# taster_name               95071
# taster_twitter_handle     90542
# title                    119988
# variety                  119987
# winery                   119988
# dtype: int64

# %%
df.columns
# Out:
# Index(['country', 'description', 'designation', 'random_col', 'points',
#        'price', 'province', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %% [markdown]
# # pd.crosstab() :- used to compute a simple cross tabulation of two (or more) factors.

# %%
"""It gives you a frequency table that is a cross-tabulation of two variables"""
pd.crosstab(df['country'], df['variety'])
# Out:
# variety                 Abouriou  Agiorgitiko  Aglianico  Aidani  Airen  \
# country
# Argentina                      0            0          0       0      0
# Armenia                        0            0          0       0      0
# Australia                      0            0          0       0      0
# Austria                        0            0          0       0      0
# Bosnia and Herzegovina         0            0          0       0      0
# Brazil                         0            0          0       0      0
# Bulgaria                       0            0          0       0      0
# Canada                         0            0          0       0      0
# Chile                          0            0          0       0      0
# China                          0            0          0       0      0
# Croatia                        0            0          0       0      0
# Cyprus                         0            0          0       0      0
# ...

# %% [markdown]
# # df.sum() :- To display the summation of specified Columns.

# %%
"""The sum() method adds all values in each column and returns the sum for each column."""
df['price'].sum(axis=0)
# Out:
# 4298233.5

# %% [markdown]
# # df.corr() :- To check co-relation between each value in df.

# %%
"""The corr() method calculates the relationship between each column in your data set."""
df.corr()
# Out:
#             random_col    points     price
# random_col    1.000000  0.005317  0.000979
# points        0.005317  1.000000  0.402995
# price         0.000979  0.402995  1.000000

# %%
# """Update the DataFrame with the data from another DataFrame"""
# df1.update(df2)

# %%
# """Remove the rows before position 3 and after position 5 of the DataFrame:"""
# newdf = df.truncate(before=3, after=5)

# %%
"""Convert the columns into rows and vice versa:"""
newdf = df.T

# %%
"""Sort the DataFrame by index labels:"""
newdf = df.sort_index()

# %% [markdown]
# # df.round() :- to round off the value.

# %%
"""Round each number in the DataFrame into 1 decimal numbers:"""
df['price'].round(1)
# Out:
# 19512     65.0
# 55673     21.0
# 25497     19.0
# 48301     20.0
# 124223    16.0
#           ...
# 124176    30.0
# 129407    22.0
# 129408    22.0
# 129590    30.0
# 129900    32.0
# Name: price, Length: 119988, dtype: float64

# %%
df.columns
# Out:
# Index(['country', 'description', 'designation', 'random_col', 'points',
#        'price', 'province', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %% [markdown]
# # df.pivot_table() :- To plot pivot table to summarize the numeric value related to two different categories

# %%
"""Create a spreadsheet pivot table as a DataFrame"""
df.pivot_table(values="price",index="country",columns="variety")
# Out:
# variety                 Abouriou  Agiorgitiko  Aglianico  Aidani  Airen  \
# country
# Argentina                    NaN          NaN        NaN     NaN    NaN
# Armenia                      NaN          NaN        NaN     NaN    NaN
# Australia                    NaN          NaN        NaN     NaN    NaN
# Austria                      NaN          NaN        NaN     NaN    NaN
# Bosnia and Herzegovina       NaN          NaN        NaN     NaN    NaN
# Brazil                       NaN          NaN        NaN     NaN    NaN
# Bulgaria                     NaN          NaN        NaN     NaN    NaN
# Canada                       NaN          NaN        NaN     NaN    NaN
# Chile                        NaN          NaN        NaN     NaN    NaN
# China                        NaN          NaN        NaN     NaN    NaN
# Croatia                      NaN          NaN        NaN     NaN    NaN
# Cyprus                       NaN          NaN        NaN     NaN    NaN
# ...

# %% [markdown]
# # .max() :- To get maximum available value.

# %%
"""Return the highest value for each column:"""
df['price'].max()
# Out:
# 3300.0

# %% [markdown]
# # .min() :- To get minimum available value.

# %%
"""Return the lowest value for each column:"""
df['price'].min()
# Out:
# 4.0

# %%
# """Add the content of one DataFrame to another:"""
# newdf = df1.join(df2)

# %%
"""Merge DataFrame or named Series objects with a database-style join."""
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [5, 6, 7, 8]})
df1.merge(df2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7

# %% [markdown]
# # pd.get_dummies :- To convert categorical variable into numerical indicators.

# %%
"""Convert categorical variable into dummy/indicator variables."""
s = pd.Series(list('pqrp'))
pd.get_dummies(s)
# Out:
#    p  q  r
# 0  1  0  0
# 1  0  1  0
# 2  0  0  1
# 3  1  0  0

# %% [markdown]
# # pd.concate() :- To add multiple columns wrt axis.

# %%
"""pandas.concat() function does all the heavy lifting of performing concatenation operations along with an axis"""
# creating the Series
series1 = pd.Series([1, 2, 3])
display('series1:', series1)
series2 = pd.Series(['A', 'B', 'C'])
display('series2:', series2)
  
# concatenating
display('After concatenating:')
display(pd.concat([series1, series2]))
# Out:
# 'series1:'
# 0    1
# 1    2
# 2    3
# dtype: int64
# 'series2:'
# 0    A
# 1    B
# 2    C
# dtype: object
# 'After concatenating:'
# 0    1
# 1    2
# 2    3
# 0    A
# 1    B
# 2    C
# dtype: object

# %% [markdown]
# # lambda :- a small anonymous function that can take any number of arguments and execute an expression.

# %%
"""Lambda function"""
# creating and initializing a nested list
values_list = [[15, 2.5, 100], [20, 4.5, 50], [25, 5.2, 80],
               [45, 5.8, 48], [40, 6.3, 70], [41, 6.4, 90],
               [51, 2.3, 111]]
 
# creating a pandas dataframe
df = pd.DataFrame(values_list, columns=['Field_1', 'Field_2', 'Field_3'])
 
# Applying lambda function to find
# the product of 3 columns using
# df.assign()
df = df.assign(Product=lambda x: (x['Field_1'] * x['Field_2'] * x['Field_3']))

# %% [markdown]
# # pd.map :- substitute each value in a Series with another value.

# %%
"""pandas.map() is used to map values from two series having one column same. """
pokemon_names = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", usecols = ["country"],squeeze = True)
  
#usecol is used to use selected columns
#index_col is used to make passed column as index
# pokemon_types = pd.read_csv("pokemon.csv", index_col = "Pokemon",squeeze = True)
  
#using pandas map function
# new=pokemon_names.map(pokemon_types)
